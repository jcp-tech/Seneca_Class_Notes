# %%
# https://machinelearningmastery.com/visualize-gradient-boosting-decision-trees-xgboost-python/

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.3-py3-none-macosx_12_0_arm64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /Users/mac/miniforge3/envs/phd/lib/python3.8/site-packages (from xgboost) (1.23.2)
# Requirement already satisfied: scipy in /Users/mac/miniforge3/envs/phd/lib/python3.8/site-packages (from xgboost) (1.10.1)
# Downloading xgboost-2.0.3-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.5 MB/s eta 0:00:00m eta 0:00:010:01
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3

# %%
# plot decision tree
from numpy import loadtxt
from xgboost import XGBClassifier
from xgboost import plot_tree
import matplotlib.pyplot as plt

# load data
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")

# split data into X and y
X = dataset[:,0:8]
y = dataset[:,8]

# fit model no training data
model = XGBClassifier()
model.fit(X, y)

# plot single tree
fig, ax = plt.subplots(figsize=(60, 120))
plot_tree(model, num_trees=4, ax=ax)
plt.show()

# %%
plot_tree(model, num_trees=4)
# Out:
# <Axes: >

# %%
plot_tree(model, num_trees=0, rankdir='LR')
# Out:
# <Axes: >
