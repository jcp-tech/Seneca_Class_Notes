# %% [markdown]
# # Lab 4
# Working With Missing data
#
# ### Learning objectives
# Upon successful completion of this lab, you will have demonstrated the abilities to:
# 1. Create missing values.
# 2. Recode and make calculations with missing values

# %%
import pandas as pd
import numpy as np

# %%
ebola = pd.read_csv('country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           NaN         1786.0             NaN              2977.0
# 1           NaN         1781.0             NaN              2943.0
# 2           NaN         1767.0          3496.0              2915.0
# 3           NaN            NaN          3496.0                 NaN
# 4           NaN         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         NaN           66.0             6.0                 5.0
# 118         NaN           62.0             NaN                 NaN
# 119         NaN           60.0             NaN                 NaN
# 120         NaN           59.0             NaN                 NaN
# 121         NaN           29.0             NaN                 NaN
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               NaN             NaN                  NaN           NaN
# 1               NaN             NaN                  NaN           NaN
# 2               NaN             NaN                  NaN           NaN
# 3               NaN             NaN                  NaN           NaN
# 4               NaN             NaN                  NaN           NaN
# ..              ...             ...                  ...           ...
# 117             NaN             NaN                  NaN           NaN
# 118             NaN             NaN                  NaN           NaN
# 119             NaN             NaN                  NaN           NaN
# 120             NaN             NaN                  NaN           NaN
# 121             NaN             NaN                  NaN           NaN
#
#      Deaths_Mali
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 117          NaN
# 118          NaN
# 119          NaN
# 120          NaN
# 121          NaN
#
# [122 rows x 18 columns]

# %%
ebola.dtypes
# Out:
# Date                    object
# Day                      int64
# Cases_Guinea           float64
# Cases_Liberia          float64
# Cases_SierraLeone      float64
# Cases_Nigeria          float64
# Cases_Senegal          float64
# Cases_UnitedStates     float64
# Cases_Spain            float64
# Cases_Mali             float64
# Deaths_Guinea          float64
# Deaths_Liberia         float64
# Deaths_SierraLeone     float64
# Deaths_Nigeria         float64
# Deaths_Senegal         float64
# Deaths_UnitedStates    float64
# Deaths_Spain           float64
# Deaths_Mali            float64
# dtype: object

# %%
ebola.shape
# Out:
# (122, 18)

# %%
ebola.count()
# Out:
# Date                   122
# Day                    122
# Cases_Guinea            93
# Cases_Liberia           83
# Cases_SierraLeone       87
# Cases_Nigeria           38
# Cases_Senegal           25
# Cases_UnitedStates      18
# Cases_Spain             16
# Cases_Mali              12
# Deaths_Guinea           92
# Deaths_Liberia          81
# Deaths_SierraLeone      87
# Deaths_Nigeria          38
# Deaths_Senegal          22
# Deaths_UnitedStates     18
# Deaths_Spain            16
# Deaths_Mali             12
# dtype: int64

# %%
num_rows = ebola.shape[0]
num_missing = num_rows - ebola.count()
print(num_missing)
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %% [markdown]
# 1. Below is another way to count missing data in each of the columns of ebola dataset. Modify the code to display the percentage of missing values for each of the columns in ebola dataset.

# %%
# Alternatively, you can use the isnull method to find missing values.
missing_val_count_by_column = ebola.isnull().sum()
missing_val_count_by_column
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
# Modify the code to display the percentage of missing values for each of the columns in ebola dataset.
num_missing = missing_val_count_by_column.copy()
num_rows, num_columns = ebola.shape
percentage_missing = (num_missing / num_rows)*100
percentage_missing
# Out:
# Date                    0.000000
# Day                     0.000000
# Cases_Guinea           23.770492
# Cases_Liberia          31.967213
# Cases_SierraLeone      28.688525
# Cases_Nigeria          68.852459
# Cases_Senegal          79.508197
# Cases_UnitedStates     85.245902
# Cases_Spain            86.885246
# Cases_Mali             90.163934
# Deaths_Guinea          24.590164
# Deaths_Liberia         33.606557
# Deaths_SierraLeone     28.688525
# Deaths_Nigeria         68.852459
# Deaths_Senegal         81.967213
# Deaths_UnitedStates    85.245902
# Deaths_Spain           86.885246
# Deaths_Mali            90.163934
# dtype: float64

# %% [markdown]
# 2. What is the percentage of missing values for each of the  columns in ebola dataset.
#
# Use a for loop and np.count_nonzero() function.
# Your output should show the column name and the percentage of missing values.

# %%
ebola.columns # is a list of column names
# Out:
# Index(['Date', 'Day', 'Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone',
#        'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain',
#        'Cases_Mali', 'Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone',
#        'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates',
#        'Deaths_Spain', 'Deaths_Mali'],
#       dtype='object')

# %%
np.count_nonzero(ebola['Deaths_Mali'].isnull())
# Out:
# 110

# %%
# Percentage of missing values for each column
for col in ebola.columns:
    num_missing = np.count_nonzero(ebola[col].isnull())
    if num_missing > 0:
        percentage_missing = (num_missing / num_rows)*100
        print(col, f"{percentage_missing:.2f}%")
# Out:
# Cases_Guinea 23.77%
# Cases_Liberia 31.97%
# Cases_SierraLeone 28.69%
# Cases_Nigeria 68.85%
# Cases_Senegal 79.51%
# Cases_UnitedStates 85.25%
# Cases_Spain 86.89%
# Cases_Mali 90.16%
# Deaths_Guinea 24.59%
# Deaths_Liberia 33.61%
# Deaths_SierraLeone 28.69%
# Deaths_Nigeria 68.85%
# Deaths_Senegal 81.97%
# Deaths_UnitedStates 85.25%
# Deaths_Spain 86.89%
# Deaths_Mali 90.16%

# %% [markdown]
# 3. Show the columns that have more than 90% missing values.
#
# Write a for loop on missing_val_count_by_column pandas Series from above.
# missing_val_count_by_column.index will give the list of column names
# and
# missing_val_count_by_column[i] will give the count of missing values where i is a column name.

# %%
missing_val_count_by_column
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
missing_val_count_by_column.index
# Out:
# Index(['Date', 'Day', 'Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone',
#        'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain',
#        'Cases_Mali', 'Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone',
#        'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates',
#        'Deaths_Spain', 'Deaths_Mali'],
#       dtype='object')

# %%
missing_val_count_by_column['Date']
# Out:
# np.int64(0)

# %%
print("Columns Having more than 90% missing values = ")
for i in missing_val_count_by_column.index: # for col, val in missing_val_count_by_column.items():
    percentage_missing = (missing_val_count_by_column[i]/num_rows)*100 # (val / num_rows)*100
    if percentage_missing > 90:
        print(i) # print(col, f"{percentage_missing:.2f}%")
# Out:
# Columns Having more than 90% missing values =
# Cases_Mali
# Deaths_Mali

# %% [markdown]
# 4. Drop the columns that have more than 90% missing values.
#
#         - define a list columns_to_drop containing the column names to drop
#         - Create a new dataframe ebola_droppedCol
#         - display the shape of the new dataframe.
#         - print the number of missing values in ebola_droppedCol

# %%
columns_to_drop = [col for col, val in missing_val_count_by_column.items() if (val/num_rows)*100 > 90]
columns_to_drop
# Out:
# ['Cases_Mali', 'Deaths_Mali']

# %%
if all(column in ebola.columns for column in columns_to_drop):
    ebola_droppedCol = ebola.copy().drop(columns_to_drop, axis=1)
ebola_droppedCol
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 0           1786.0             NaN              2977.0             NaN
# 1           1781.0             NaN              2943.0             NaN
# 2           1767.0          3496.0              2915.0             NaN
# 3              NaN          3496.0                 NaN             NaN
# 4           1739.0          3471.0              2827.0             NaN
# ..             ...             ...                 ...             ...
# 117           66.0             6.0                 5.0             NaN
# 118           62.0             NaN                 NaN             NaN
# 119           60.0             NaN                 NaN             NaN
# 120           59.0             NaN                 NaN             NaN
# 121           29.0             NaN                 NaN             NaN
#
#      Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain
# 0               NaN                  NaN           NaN
# 1               NaN                  NaN           NaN
# 2               NaN                  NaN           NaN
# 3               NaN                  NaN           NaN
# 4               NaN                  NaN           NaN
# ..              ...                  ...           ...
# 117             NaN                  NaN           NaN
# 118             NaN                  NaN           NaN
# 119             NaN                  NaN           NaN
# 120             NaN                  NaN           NaN
# 121             NaN                  NaN           NaN
#
# [122 rows x 16 columns]

# %%
ebola_droppedCol.shape
# Out:
# (122, 16)

# %%
ebola_droppedCol.isnull().sum()
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# dtype: int64

# %% [markdown]
# #### Fill Backward

# %% [markdown]
# 5. Answer each of the following questions:
#     - Count the number of missing values in the dataframe after the fill backward imputation of missing values. show the first 10 rows and 5 columns after imputation.
#     - Explain what changes have been made after fill backward imputation of the missing values and why.

# %%
ebola.iloc[0:10, 0:6]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0            NaN             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0            NaN             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0
#
#    Cases_Nigeria
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %%
ebola_fillType1 = ebola.fillna(method='bfill')
ebola_fillType1
# Out:
# C:\Users\JonathanChackoPattas\AppData\Local\Temp\ipykernel_16680\2947091177.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ebola_fillType1 = ebola.fillna(method='bfill')
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0         8166.0            10030.0
# 1      1/4/2015  288        2775.0         8166.0             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2730.0         8157.0             9633.0
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0             20.0            1.0                 4.0          1.0
# 1             20.0            1.0                 4.0          1.0
# 2             20.0            1.0                 4.0          1.0
# 3             20.0            1.0                 4.0          1.0
# 4             20.0            1.0                 4.0          1.0
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           7.0         1786.0          3496.0              2977.0
# 1           7.0         1781.0          3496.0              2943.0
# 2           7.0         1767.0          3496.0              2915.0
# 3           7.0         1739.0          3496.0              2827.0
# 4           7.0         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         NaN           66.0             6.0                 5.0
# 118         NaN           62.0             NaN                 NaN
# 119         NaN           60.0             NaN                 NaN
# 120         NaN           59.0             NaN                 NaN
# 121         NaN           29.0             NaN                 NaN
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               8.0             0.0                  1.0           0.0
# 1               8.0             0.0                  1.0           0.0
# 2               8.0             0.0                  1.0           0.0
# 3               8.0             0.0                  1.0           0.0
# 4               8.0             0.0                  1.0           0.0
# ..              ...             ...                  ...           ...
# 117             NaN             NaN                  NaN           NaN
# 118             NaN             NaN                  NaN           NaN
# 119             NaN             NaN                  NaN           NaN
# 120             NaN             NaN                  NaN           NaN
# 121             NaN             NaN                  NaN           NaN
#
#      Deaths_Mali
# 0            6.0
# 1            6.0
# 2            6.0
# 3            6.0
# 4            6.0
# ..           ...
# 117          NaN
# 118          NaN
# 119          NaN
# 120          NaN
# 121          NaN
#
# [122 rows x 18 columns]

# %%
missing_values_after_bfill = ebola_fillType1.isnull().sum()
print(f"Indivdual number of missing values after fill backward imputation:")
missing_values_after_bfill # Breakdown
# Out:
# Indivdual number of missing values after fill backward imputation:
# Date                    0
# Day                     0
# Cases_Guinea            0
# Cases_Liberia           4
# Cases_SierraLeone       4
# Cases_Nigeria          50
# Cases_Senegal          63
# Cases_UnitedStates     76
# Cases_Spain            80
# Cases_Mali             88
# Deaths_Guinea           0
# Deaths_Liberia          4
# Deaths_SierraLeone      4
# Deaths_Nigeria         50
# Deaths_Senegal         65
# Deaths_UnitedStates    76
# Deaths_Spain           80
# Deaths_Mali            88
# dtype: int64

# %%
print("Total number of missing values after fill backward imputation:")
int(missing_values_after_bfill.sum()) # Total
# Out:
# Total number of missing values after fill backward imputation:
# 732

# %%
ebola_fillType1.iloc[:10, :5]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0         8166.0            10030.0
# 1    1/4/2015  288        2775.0         8166.0             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2730.0         8157.0             9633.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0         7977.0             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0         7862.0             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0

# %%
# The Changes made after the backward fill imputation havn't removed all the missing values from the DataFrame & is evident from the end of the DataFrame.

# %% [markdown]
# #### Fill forward

# %% [markdown]
# 6. Answer each of the following questions:
#     - Count the number of missing values in the dataframe after the fill forward imputation of missing values. Show the first 10 rows and 5 columns after imputation.
#     - Explain what changes have been made after fill forward imputation of the missing values and why.

# %%
ebola.iloc[0:10, 0:6]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0            NaN             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0            NaN             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0
#
#    Cases_Nigeria
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %%
ebola_fillType1 = ebola_fillType1.fillna(method='ffill')
ebola_fillType1
# Out:
# C:\Users\JonathanChackoPattas\AppData\Local\Temp\ipykernel_16680\749275961.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ebola_fillType1 = ebola_fillType1.fillna(method='ffill')
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0         8166.0            10030.0
# 1      1/4/2015  288        2775.0         8166.0             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2730.0         8157.0             9633.0
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            8.0                6.0
# 119   3/25/2014    3          86.0            8.0                6.0
# 120   3/24/2014    2          86.0            8.0                6.0
# 121   3/22/2014    0          49.0            8.0                6.0
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0             20.0            1.0                 4.0          1.0
# 1             20.0            1.0                 4.0          1.0
# 2             20.0            1.0                 4.0          1.0
# 3             20.0            1.0                 4.0          1.0
# 4             20.0            1.0                 4.0          1.0
# ..             ...            ...                 ...          ...
# 117            0.0            1.0                 1.0          1.0
# 118            0.0            1.0                 1.0          1.0
# 119            0.0            1.0                 1.0          1.0
# 120            0.0            1.0                 1.0          1.0
# 121            0.0            1.0                 1.0          1.0
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           7.0         1786.0          3496.0              2977.0
# 1           7.0         1781.0          3496.0              2943.0
# 2           7.0         1767.0          3496.0              2915.0
# 3           7.0         1739.0          3496.0              2827.0
# 4           7.0         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         1.0           66.0             6.0                 5.0
# 118         1.0           62.0             6.0                 5.0
# 119         1.0           60.0             6.0                 5.0
# 120         1.0           59.0             6.0                 5.0
# 121         1.0           29.0             6.0                 5.0
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               8.0             0.0                  1.0           0.0
# 1               8.0             0.0                  1.0           0.0
# 2               8.0             0.0                  1.0           0.0
# 3               8.0             0.0                  1.0           0.0
# 4               8.0             0.0                  1.0           0.0
# ..              ...             ...                  ...           ...
# 117             0.0             0.0                  0.0           1.0
# 118             0.0             0.0                  0.0           1.0
# 119             0.0             0.0                  0.0           1.0
# 120             0.0             0.0                  0.0           1.0
# 121             0.0             0.0                  0.0           1.0
#
#      Deaths_Mali
# 0            6.0
# 1            6.0
# 2            6.0
# 3            6.0
# 4            6.0
# ..           ...
# 117          1.0
# 118          1.0
# 119          1.0
# 120          1.0
# 121          1.0
#
# [122 rows x 18 columns]

# %%
missing_values_after_ffill = ebola_fillType1.isnull().sum()
print(f"Indivdual number of missing values after fill forward imputation:")
missing_values_after_ffill # Breakdown
# Out:
# Indivdual number of missing values after fill forward imputation:
# Date                   0
# Day                    0
# Cases_Guinea           0
# Cases_Liberia          0
# Cases_SierraLeone      0
# Cases_Nigeria          0
# Cases_Senegal          0
# Cases_UnitedStates     0
# Cases_Spain            0
# Cases_Mali             0
# Deaths_Guinea          0
# Deaths_Liberia         0
# Deaths_SierraLeone     0
# Deaths_Nigeria         0
# Deaths_Senegal         0
# Deaths_UnitedStates    0
# Deaths_Spain           0
# Deaths_Mali            0
# dtype: int64

# %%
print("Total number of missing values after fill forward imputation:")
int(missing_values_after_ffill.sum()) # Total
# Out:
# Total number of missing values after fill forward imputation:
# 0

# %%
ebola_fillType1.iloc[:10, :5]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0         8166.0            10030.0
# 1    1/4/2015  288        2775.0         8166.0             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2730.0         8157.0             9633.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0         7977.0             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0         7862.0             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0

# %%
# The Changes made after the fill forward imputation have removed all the missing values from the DataFrame (since a Backward fill was performed first).

# %% [markdown]
# 7. Answer each of the following questions:
#     - Replace the missing values with backward fill method, next apply forward fill method.
#     - print the number of missing values after imputation.

# %%
ebola_fillType3 = ebola.fillna(method='bfill').fillna(method='ffill')
ebola_fillType3
# Out:
# C:\Users\JonathanChackoPattas\AppData\Local\Temp\ipykernel_16680\870735893.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ebola_fillType3 = ebola.fillna(method='bfill').fillna(method='ffill')
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0         8166.0            10030.0
# 1      1/4/2015  288        2775.0         8166.0             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2730.0         8157.0             9633.0
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            8.0                6.0
# 119   3/25/2014    3          86.0            8.0                6.0
# 120   3/24/2014    2          86.0            8.0                6.0
# 121   3/22/2014    0          49.0            8.0                6.0
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0             20.0            1.0                 4.0          1.0
# 1             20.0            1.0                 4.0          1.0
# 2             20.0            1.0                 4.0          1.0
# 3             20.0            1.0                 4.0          1.0
# 4             20.0            1.0                 4.0          1.0
# ..             ...            ...                 ...          ...
# 117            0.0            1.0                 1.0          1.0
# 118            0.0            1.0                 1.0          1.0
# 119            0.0            1.0                 1.0          1.0
# 120            0.0            1.0                 1.0          1.0
# 121            0.0            1.0                 1.0          1.0
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           7.0         1786.0          3496.0              2977.0
# 1           7.0         1781.0          3496.0              2943.0
# 2           7.0         1767.0          3496.0              2915.0
# 3           7.0         1739.0          3496.0              2827.0
# 4           7.0         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         1.0           66.0             6.0                 5.0
# 118         1.0           62.0             6.0                 5.0
# 119         1.0           60.0             6.0                 5.0
# 120         1.0           59.0             6.0                 5.0
# 121         1.0           29.0             6.0                 5.0
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               8.0             0.0                  1.0           0.0
# 1               8.0             0.0                  1.0           0.0
# 2               8.0             0.0                  1.0           0.0
# 3               8.0             0.0                  1.0           0.0
# 4               8.0             0.0                  1.0           0.0
# ..              ...             ...                  ...           ...
# 117             0.0             0.0                  0.0           1.0
# 118             0.0             0.0                  0.0           1.0
# 119             0.0             0.0                  0.0           1.0
# 120             0.0             0.0                  0.0           1.0
# 121             0.0             0.0                  0.0           1.0
#
#      Deaths_Mali
# 0            6.0
# 1            6.0
# 2            6.0
# 3            6.0
# 4            6.0
# ..           ...
# 117          1.0
# 118          1.0
# 119          1.0
# 120          1.0
# 121          1.0
#
# [122 rows x 18 columns]

# %%
current_missing_values = ebola_fillType3.isnull().sum()
current_missing_values
# Out:
# Date                   0
# Day                    0
# Cases_Guinea           0
# Cases_Liberia          0
# Cases_SierraLeone      0
# Cases_Nigeria          0
# Cases_Senegal          0
# Cases_UnitedStates     0
# Cases_Spain            0
# Cases_Mali             0
# Deaths_Guinea          0
# Deaths_Liberia         0
# Deaths_SierraLeone     0
# Deaths_Nigeria         0
# Deaths_Senegal         0
# Deaths_UnitedStates    0
# Deaths_Spain           0
# Deaths_Mali            0
# dtype: int64

# %%
int(current_missing_values.sum()) # TOTAL
# Out:
# 0

# %% [markdown]
# 8. Replace the missing values using a linear interpolation and print the top rows of the dataset.

# %%
ebola_fillType4 = ebola.interpolate()
ebola_fillType4.head()
# Out:
# C:\Users\JonathanChackoPattas\AppData\Local\Temp\ipykernel_16680\3175503351.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   ebola_fillType4 = ebola.interpolate()
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2749.5         8157.0             9677.5
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 0         1786.0             NaN              2977.0             NaN
# 1         1781.0             NaN              2943.0             NaN
# 2         1767.0          3496.0              2915.0             NaN
# 3         1753.0          3496.0              2871.0             NaN
# 4         1739.0          3471.0              2827.0             NaN
#
#    Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 0             NaN                  NaN           NaN          NaN
# 1             NaN                  NaN           NaN          NaN
# 2             NaN                  NaN           NaN          NaN
# 3             NaN                  NaN           NaN          NaN
# 4             NaN                  NaN           NaN          NaN

# %% [markdown]
# #### Short answer questions

# %% [markdown]
# 9. Write a paragraph to highlight the differences between the fill foward/backward versus linear interpolation of the missing values.

# %%
# The fill forward and fill backward methods are simple imputation techniques that replace missing values with the last known value (forward fill) or the next known value (backward fill). These methods are particularly useful for time series data where the assumption is that the previous or next value is a reasonable estimate for the missing value. However, these methods can introduce bias if the data has a trend or seasonality, as they do not account for changes over time.
# On the other hand, linear interpolation estimates missing values by assuming a linear relationship between the known data points. This method calculates the missing value based on the slope between the two nearest known values, providing a more accurate estimate when the data follows a linear trend. Linear interpolation is more sophisticated than fill forward/backward as it considers the overall data pattern, but it may not be suitable for data with non-linear trends or significant fluctuations.
# In summary, fill forward/backward methods are simpler and faster but may introduce bias in trending data, while linear interpolation provides a more accurate estimate by considering the data trend but may not handle non-linear patterns well.

# %% [markdown]
# 10. Time series interpolation works by calling interpolate with the option method='time'.
#     - Explain how is it different than the linear interpolation?
#     - when do linear and time interpolation give the same results?

# %%
# ebola['Date'] = pd.to_datetime(ebola['Date'])
# ebola.set_index('Date', inplace=True)
# ebola_fillType5 = ebola.interpolate(method='time')
# ebola_fillType5.head()

# %%
# -> Time series interpolation looks at the actual times between data points to fill in gaps, so it's really good for data that changes over time. Linear interpolation just draws a straight line between points, ignoring the time gaps.

# -> They give the same results when the data is evenly spaced in time and follows a straight line trend, because then both methods end up doing the same calculation.
